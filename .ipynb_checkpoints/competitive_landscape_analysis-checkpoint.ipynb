# %% [markdown]
# ## Data Import

# %%
import numpy as np
import pandas as pd 

import re
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer 
from gensim import corpora, similarities
from gensim.models import LdaModel, CoherenceModel

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
from sklearn.manifold import MDS

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
from wordcloud import WordCloud
import mpld3
from mpld3 import plugins, display
import pyLDAvis
import pyLDAvis.gensim

import warnings
warnings.simplefilter('ignore')

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/charlottefeng/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/charlottefeng/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/charlottefeng/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_excel('data/landscape_data.xlsx')

# %%
df
# Out:
#                                          organization  priority  \
# 0                                          JerseySTEM         0
# 1                              After School All Stars         1
# 2                          FIRST Robotics Competition         1
# 3                                      Girls Who Code         1
# 4                                           TechGirlz         1
# 5                               South Jersey Robotics         1
# 6                                  Students 2 Science         1
# 7                                        Bedtime Math         2
# 8                                        Girls Scouts         2
# 9                                    The Coder School         2
# 10                                        STEMKidsNYC         2
# 11          STEM ALLIANCE OF LARCHMONT-MAMARONECK INC         2
# 12                                       Digital Girl         2
# 13                                    STEAMPark, Inc.         3
# 14                                  STEAMWorks Studio         3
# 15                                           STEM Gen         3
# 16                                    Geeks Rule, Inc         3
# 17                                         4th Family         3
# 18                                 Aviation Influence         3
# 19  Schoharie Mohawk Initiative for Science and Te...         3
# 20                                 The Mentor Project         3
# 21                             Victor Cruz Foundation         3
#
#                                               mission  \
# 0   JerseySTEM is a non-profit organization that p...
# 1   After-School All-Stars provides free, comprehe...
# 2   FIRST LEGO League introduces science, technolo...
# 3   Girls Who Code is on a mission to close the ge...
# 4   TechGirlz is a nonprofit program of Creating I...
# 5   Our Vision:\nTransform the culture in South Je...
# 6   Students 2 Science, Inc. is a 501(c)(3) model ...
# 7   Our charitable mission is to help kids love nu...
# 8   Girl Scouts offers the best leadership develop...
# 9   We are an after-school drop-off (and virtual) ...
# 10  STEM Kids NYC is a 501(c)(3) organization that...
# 11  The STEM Alliance is a grass-roots, 501(c)(3) ...
# 12  Digital Girl, Incorporated was founded in 2014...
# 13  STEAMpark, INC  provides educational, emotiona...
# 14  Our mission\nOur mission is to spark creativit...
# 15  We believe that every child deserves a good ed...
# 16  Geeks Rule promotes the study of and engagemen...
# 17  4th Family Incorporated is a not-for-profit or...
# 18  Our Mission\nTo serve our young people in disc...
# 19  It started with an idea:  to encourage student...
# 20  The MENTOR Project is a registered 501(c)(3) n...
# 21  The Victor Cruz Foundation is driven to impact...
#
#                                              programs
# 0   MySTEMClub\nLearn Teamwork, Problem Solving, a...
# 1   We Are Ready (W.A.R.) prepares at-risk 8th gra...
# 2   FIRST LEGO League is a program that engages st...
# 3   After-school clubs for 3rd–12th grade girls to...
# 4   TechShopz are free, hands-on technology worksh...
# 5   SJR supports 18 FIRST Robotics teams consistin...
# 6   ISAAC engages middle and high school students ...
# 7   We make math part of the family routine. Every...
# 8   Development of the Girl Scout Leadership Exper...
# 9   Rather than using static one-size-fits-all cur...
# 10  Our hands-on, student centered afterschool pro...
# 11  THE STEM ALLIANCE IS HIRED PY THE MAMARONECK U...
# 12  After School and Summer Enrichment Program (AS...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   organization  22 non-null     object
#  1   priority      22 non-null     int64
#  2   mission       22 non-null     object
#  3   programs      13 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 832.0+ bytes

# %%
df.shape
# Out:
# (22, 4)

# %% [markdown]
# ### About data
# - `mission` is scraped from organization websites in sections of "what we do"/"mission"/"vision".
# - `program` is scraped from GuideStar.
# - Though this is done manually, scrapers can be developed to automate the process.
# - For demonstration purpose, this analysis will be carried out on organizations with `priority != 3`

# %%
df = df[df['priority'] != 3]

# %%
# Reset index as some rows were skipped
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (13, 4)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Text Cleaning
# - Lowercase
# - Remove punctuations, special characters and digits
# - Tokenization
# - Lemmatization
# - Remove stopwords. Also exclude
#     - Organization names (and their acronyms)
#     - Some other frequent words we are not interested in, i.e., words that are likely to appear for almost every document
#     - *Remark: we don't want the repetitive occurences of these words to affect token frequency later.*
#         -  ['nonprofit','non','profit','inc','program','mission', 'organization','world','today','day','jersey','student','kid','education','year','age']
# - Vectorization: TF-IDF

# %% [markdown]
# #### Helper Functions

# %%
def lemma_tokenizer(text, min_char=3):
    """
    Performs tokenization and lemmatization.
    @min_char: minimum character of a token
    """
    lemmer = WordNetLemmatizer()
    return [lemmer.lemmatize(t) for t in word_tokenize(text)\
            if (len(t) >= min_char)]

# %%
def get_acronyms(str_list):
    """
    Gets the acronyms of a list of strings
    """
    acronyms = []
    for s in str_list:
        s_ls = s.split(' ')
        if len(s_ls) > 1:
            acrn = ''.join([w[0] for w in s_ls])
            acronyms.append(acrn)
    return acronyms

# %%
def stopwords_remover(tokens, stop_words):
    """
    Removes stopwords in a list of tokens
    """
    return [word for word in tokens if not word in stop_words]

# %%
def preprocessor(text):
    """
    Transforms text into lowercase.
    Removes punctuations, special characters and digits.
    """
    return re.sub(r'[^A-Za-z]+', ' ', text.lower())

# %%
def preprocess(df, target, vectorize=True):
    """
    Preprocesses text columns.
    1. Lowercase
    2. Remove punctuations, special characters and digits
    3. Tokenize
    4. Lemmatize
    5. Remove stopwords
    6. Vectorize
    @target: target column to preprocess
    @vectorize: whether or not to vectorize the tokens
    """
    # Create a list of stopwords to remove
    stop_words = stopwords.words('english')
    to_exclude = ['nonprofit','non','profit','inc','program',\
                  'mission', 'organization','world','today','day',\
                  'jersey','school','student','kid','education'\
                  'year', 'age']
    org = df.organization.tolist()
    org_acrn = get_acronyms(org)
    to_exclude.extend(org)
    to_exclude.extend(org_acrn)
    stop_words.extend(to_exclude)
    stop_words = [w.lower() for w in stop_words]
    print(f'Stopwords removed:\n{stop_words}')
    
    # Preprocess: 1-5
    new_c = '_'.join([target, 'cleaned'])
    df[new_c] = df[target].apply(preprocessor)
    df[new_c] = df[new_c].apply(lemma_tokenizer)
    df[new_c] = df[new_c].apply(stopwords_remover, stop_words=stop_words)
    
    # Vectorize
    if vectorize:
        tfidf = TfidfVectorizer(
            preprocessor=preprocessor,
            tokenizer=lemma_tokenizer,
            stop_words=stop_words,
            min_df=2) # ngram_range=(1, 3)
        tfidf_matrix = tfidf.fit_transform(df[target])
        
        return df, tfidf, tfidf_matrix

    return df

# %%
df_cleaned, mis_tfidf, mis_mat = preprocess(df, 'mission')
# Out:
# Stopwords removed:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'nonprofit', 'non', 'profit', 'inc', 'program', 'mission', 'organization', 'world', 'today', 'day', 'jersey', 'school', 'student', 'kid', 'educationyear', 'age', 'jerseystem', 'after school all stars', 'first robotics competition', 'girls who code', 'techgirlz', 'south jersey robotics', 'students 2 science', 'bedtime math', 'girls scouts', 'the coder school', 'stemkidsnyc', 'stem alliance of larchmont-mamaroneck inc', 'digital girl', 'asas', 'frc', 'gwc', 'sjr', 's2s', 'bm', 'gs', 'tcs', 'saoli', 'dg']

# %%
df_cleaned[['mission', 'mission_cleaned']].head(5)
# Out:
#                                              mission  \
# 0  JerseySTEM is a non-profit organization that p...
# 1  After-School All-Stars provides free, comprehe...
# 2  FIRST LEGO League introduces science, technolo...
# 3  Girls Who Code is on a mission to close the ge...
# 4  TechGirlz is a nonprofit program of Creating I...
#
#                                      mission_cleaned
# 0  [promotes, excellence, science, technology, en...
# 1  [star, provides, free, comprehensive, keep, ch...
# 2  [first, lego, league, introduces, science, tec...
# 3  [girl, code, close, gender, gap, technology, c...
# 4  [creating, future, comptia, inspires, middle, ...

# %% [markdown]
# ### WordCloud

# %%
def plot_wordcloud(text, title):
    """
    Plots the wordcloud for a given text dataframe/array/list
    @title: plot title
    """
    # Concatenate into a single string
    text_str = ''.join(str(t) for t in text) 
    
    # Remove some unwanted words by POS
    # pos to keep: adj, adv, n(p)
    pos = ['JJ', 'JJR', 'JJS', 'NN', 'NNS', \
           'NNP', 'NNPS', 'PDT', 'POS',\
           'RB', 'RBR', 'RBS'] 
    tokens = word_tokenize(text_str)
    tokens_tag = pos_tag(tokens)
    tokens_filtered = [t[0] for t in tokens_tag if t[1] in pos]
    text_filtered = ' '.join(str(t) for t in tokens_filtered)
    
    wordcloud = WordCloud(max_words=100,
                          max_font_size=100, width=1000, height=500,
                          background_color='white').generate(text_filtered)

    plt.figure(figsize=(12, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Wordcloud for {title}', fontsize=15)
    plt.savefig(f'img/wc_{title}.png', dpi=200)
    plt.show()

# %%
plot_wordcloud(df_cleaned.mission_cleaned, 'Mission')

# %% [markdown]
# ## Similarity Analysis for Missions

# %%
mis_vocab = mis_tfidf.get_feature_names()

# %%
mis_mat.shape
# Out:
# (13, 78)

# %%
mis_dist = 1 - cosine_similarity(mis_mat)

# %%
mis_dist.shape
# Out:
# (13, 13)

# %% [markdown]
# ### K-means Clustering
# - Given the small dataset, tuning is not so necessary as larger K will always lead to smaller inertia.

# %%
SEED = 42

# %%
def fit_kmeans(text_matrix, K=3, tuning=False):
    if tuning:
        K = range(2, 6)
        inertia = [] # Sum of squared distances of samples to their closest cluster center
        for k in K:
            km = KMeans(n_clusters=k,
                        random_state=SEED)
            km = km.fit(text_matrix)
            inertia.append(km.inertia_)
            
        # Elbow method
        plt.plot(K, inertia, 'bx-')
        plt.xlabel('K')
        plt.ylabel('Inertia')
        plt.title('Elbow Method for Optimal K')
        plt.show()
    else:
        km = KMeans(n_clusters=K, random_state=SEED)
        km.fit(text_matrix)
        clusters = km.labels_.tolist()

        return km, clusters

# %%
fit_kmeans(mis_mat, tuning=True)

# %%
km, clusters = fit_kmeans(mis_mat, K=5)

# %%
df_cleaned['cluster'] = clusters

# %%
df_cleaned['cluster'].value_counts()
# Out:
# 0    5
# 2    3
# 3    2
# 1    2
# 4    1
# Name: cluster, dtype: int64

# %%
def get_cluster_top_words(km, K, n=5, vocab=mis_vocab):
    # Sort words by proximity to cluster centroid
    words_ordered = km.cluster_centers_.argsort()[:,::-1] # Word index
    cluster_words = {}
    
    results = pd.DataFrame(columns=['cluster', 'words'])
    for i in range(K):
        top_n = km.cluster_centers_.argsort()[:,::-1][i,:n]
        top_n_words = ', '.join([vocab[i] for i in top_n]) # String
        cluster_words[i] = top_n_words 
    
    return cluster_words

# %%
cluster_words = get_cluster_top_words(km, 5)

# %%
cluster_words
# Out:
# {0: 'stem, education, professional, career, community',
#  1: 'first, robotics, hand, learning, skill',
#  2: 'help, life, close, look, like',
#  3: 'girl, development, leadership, free, offer',
#  4: 'learning, virtual, coding, code, youth'}

# %%
df_cleaned['cluster_keywords'] = df_cleaned['cluster'].map(cluster_words)

# %%
df_cleaned.head(5)
# Out:
#                  organization  priority  \
# 0                  JerseySTEM         0
# 1      After School All Stars         1
# 2  FIRST Robotics Competition         1
# 3              Girls Who Code         1
# 4                   TechGirlz         1
#
#                                              mission  \
# 0  JerseySTEM is a non-profit organization that p...
# 1  After-School All-Stars provides free, comprehe...
# 2  FIRST LEGO League introduces science, technolo...
# 3  Girls Who Code is on a mission to close the ge...
# 4  TechGirlz is a nonprofit program of Creating I...
#
#                                             programs  \
# 0  MySTEMClub\nLearn Teamwork, Problem Solving, a...
# 1  We Are Ready (W.A.R.) prepares at-risk 8th gra...
# 2  FIRST LEGO League is a program that engages st...
# 3  After-school clubs for 3rd–12th grade girls to...
# 4  TechShopz are free, hands-on technology worksh...
#
#                                      mission_cleaned  cluster  \
# 0  [promotes, excellence, science, technology, en...        0
# 1  [star, provides, free, comprehensive, keep, ch...        2
# 2  [first, lego, league, introduces, science, tec...        1
# 3  [girl, code, close, gender, gap, technology, c...        2
# 4  [creating, future, comptia, inspires, middle, ...        3
#
#                                    cluster_keywords
# 0  stem, education, professional, career, community
# 1                     help, life, close, look, like
# 2            first, robotics, hand, learning, skill
# 3                     help, life, close, look, like
# 4        girl, development, leadership, free, offer

# %% [markdown]
# **Which organizations are in the same cluster as JerseySTEM?**

# %%
js_cluster = int(
    df_cleaned.loc[df_cleaned['organization'] == 'JerseySTEM', 'cluster'])

# %%
df_cleaned.loc[df_cleaned['cluster'] == js_cluster,\
               ['organization', 'mission', 'cluster_keywords']]
# Out:
#                                  organization  \
# 0                                  JerseySTEM
# 6                          Students 2 Science
# 10                                STEMKidsNYC
# 11  STEM ALLIANCE OF LARCHMONT-MAMARONECK INC
# 12                               Digital Girl
#
#                                               mission  \
# 0   JerseySTEM is a non-profit organization that p...
# 6   Students 2 Science, Inc. is a 501(c)(3) model ...
# 10  STEM Kids NYC is a 501(c)(3) organization that...
# 11  The STEM Alliance is a grass-roots, 501(c)(3) ...
# 12  Digital Girl, Incorporated was founded in 2014...
#
#                                     cluster_keywords
# 0   stem, education, professional, career, community
# 6   stem, education, professional, career, community
# 10  stem, education, professional, career, community
# 11  stem, education, professional, career, community
# 12  stem, education, professional, career, community

# %% [markdown]
# ### Visualization: Multidimensional scaling

# %%
def plot_cluster(df=df_cleaned, dist=mis_dist, 
                 interactive=False):
    """
    @dist: distance matrix
    @interactive: whether or not to use mpld3 for plotting.
     Defaulted to False as for small datasets this is not helpful.
    """
    # Map dist to 2D-array (i.e., coordinates)
    mds = MDS(dissimilarity='precomputed', 
          random_state=SEED)
    coord = mds.fit_transform(dist)
    plot_df = df.copy(deep=True) # Make a copy to plot
    plot_df['_x'], plot_df['_y'] = coord[:, 0], coord[:, 1]
    
    # Create a colormap for each cluster
    n_clusters = plot_df.cluster.nunique()
    cmap = cm.get_cmap('Paired', n_clusters)
    plot_df['color'] = plot_df['cluster'].map(cmap)

    fig, ax = plt.subplots(figsize=(16, 10))
    for i in range(len(df)):
        x = plot_df.loc[plot_df.index[i], '_x']
        y = plot_df.loc[plot_df.index[i], '_y']
        lab = plot_df.loc[plot_df.index[i], 'cluster_keywords']
        clr = plot_df.loc[plot_df.index[i], 'color']
        org = plot_df.loc[plot_df.index[i], 'organization']
        padding = 0.02
        
        points = ax.plot(x, y, label=lab, color=clr,
                         marker='o', linestyle='', ms=15, mec='none')
        
        # Annotate the organizations
        if interactive:
            # Plot using mpld3. Useful for higher dimensions.
            tooltip = plugins.PointLabelTooltip(points[0], [org])
            plugins.connect(fig, tooltip)
        else:
            size = 15 if org == 'JerseySTEM' else 10
            color = 'red' if org == 'JerseySTEM' else 'black'
            ax.text(x+padding, y, org, size=size, color=color)  
    
    ax.legend()
    # Remove duplicate legends
    handles, labels = ax.get_legend_handles_labels()  
    lgd = dict(zip(labels, handles))
    ax.legend(lgd.values(), lgd.keys(), loc='lower left')
    
    ax.set_aspect('auto')
    plt.axis('off')
    plt.tight_layout()
    if interactive:
        mpld3.show()
    else:
        plt.savefig('img/cluster.png', dpi=200)
        plt.show()

# %%
plot_cluster()

# %%
plot_cluster(interactive=True)
# Out:
# Note: if you're in the IPython notebook, mpld3.show() is not the best command
#       to use. Consider using mpld3.display(), or mpld3.enable_notebook().
#       See more information at http://mpld3.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [31/Aug/2020 14:28:25] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Aug/2020 14:28:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Aug/2020 14:28:25] "GET /mpld3.js HTTP/1.1" 200 -
# stopping Server...

# %% [markdown]
# **Remarks:**
# - Organizations with the same color are of the same cluster so that they share similar missions.
# - The distance between each organization shows the difference in missions.
#     - Closer organizations are more similar in missions (also higher probability of collaboration/competition?)
# - What's more?
#     - Topic modeling using LDA
#         - To draw insights on content design (workshops, programs)

# %% [markdown]
# ## Topic Modeling for Programs (with Gensim)

# %%
df_cleaned = preprocess(df_cleaned, 'programs', False)
# Out:
# Stopwords removed:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'nonprofit', 'non', 'profit', 'inc', 'program', 'mission', 'organization', 'world', 'today', 'day', 'jersey', 'school', 'student', 'kid', 'educationyear', 'age', 'jerseystem', 'after school all stars', 'first robotics competition', 'girls who code', 'techgirlz', 'south jersey robotics', 'students 2 science', 'bedtime math', 'girls scouts', 'the coder school', 'stemkidsnyc', 'stem alliance of larchmont-mamaroneck inc', 'digital girl', 'asas', 'frc', 'gwc', 'sjr', 's2s', 'bm', 'gs', 'tcs', 'saoli', 'dg']

# %%
df_cleaned.head(5)
# Out:
#                  organization  priority  \
# 0                  JerseySTEM         0
# 1      After School All Stars         1
# 2  FIRST Robotics Competition         1
# 3              Girls Who Code         1
# 4                   TechGirlz         1
#
#                                              mission  \
# 0  JerseySTEM is a non-profit organization that p...
# 1  After-School All-Stars provides free, comprehe...
# 2  FIRST LEGO League introduces science, technolo...
# 3  Girls Who Code is on a mission to close the ge...
# 4  TechGirlz is a nonprofit program of Creating I...
#
#                                             programs  \
# 0  MySTEMClub\nLearn Teamwork, Problem Solving, a...
# 1  We Are Ready (W.A.R.) prepares at-risk 8th gra...
# 2  FIRST LEGO League is a program that engages st...
# 3  After-school clubs for 3rd–12th grade girls to...
# 4  TechShopz are free, hands-on technology worksh...
#
#                                      mission_cleaned  cluster  \
# 0  [promotes, excellence, science, technology, en...        0
# 1  [star, provides, free, comprehensive, keep, ch...        2
# 2  [first, lego, league, introduces, science, tec...        1
# 3  [girl, code, close, gender, gap, technology, c...        2
# 4  [creating, future, comptia, inspires, middle, ...        3
#
#                                    cluster_keywords  \
# 0  stem, education, professional, career, community
# 1                     help, life, close, look, like
# 2            first, robotics, hand, learning, skill
# 3                     help, life, close, look, like
# 4        girl, development, leadership, free, offer
#
#                                     programs_cleaned
# 0  [mystemclub, learn, teamwork, problem, solving...
# 1  [ready, prepares, risk, grader, success, high,...
# 2  [first, lego, league, engages, yr, fun, combin...
# 3  [club, grade, girl, explore, coding, fun, frie...
# 4  [techshopz, free, hand, technology, workshop, ...

# %%
plot_wordcloud(df_cleaned.programs_cleaned, 'Programs')

# %%
programs_text = df_cleaned.programs_cleaned
# Create dictionary
programs_dict = corpora.Dictionary(programs_text)
# Filter out extremes
programs_dict.filter_extremes(no_below=2, no_above=0.8)
# Get term frequency
programs_corpus = [programs_dict.doc2bow(t) for t in programs_text]

# %%
# Sample corpus
[(programs_dict[i], j) for i, j in programs_corpus[0]]
# Out:
# [('app', 2),
#  ('area', 1),
#  ('available', 1),
#  ('build', 1),
#  ('club', 5),
#  ('coding', 1),
#  ('college', 1),
#  ('community', 1),
#  ('course', 1),
#  ('create', 1),
#  ('environment', 1),
#  ('grade', 1),
#  ('innovation', 1),
#  ('learn', 2),
#  ('offered', 1),
#  ('opportunity', 1),
#  ('parent', 1),
#  ('problem', 1),
#  ('run', 1),
#  ('serve', 1),
#  ('stem', 1),
#  ('teamwork', 1),
#  ('virtual', 1),
#  ('volunteer', 1),
#  ('work', 1)]

# %% [markdown]
# *Remark on removal of extremes:*
#
# We filter out words with large frequencies as well as we want the topics to be specific and non-overlapping

# %% [markdown]
# ### Model

# %%
lda = LdaModel(
    corpus=programs_corpus,
    id2word=programs_dict,
    num_topics=3, 
    random_state=SEED,
    update_every=1, 
    passes=100, # training passes
    alpha='auto',
    chunksize=500 # num of documents in one pass
)

# %%
topics = lda.show_topics()
for t in topics:
    print(f'Topic {t[0]} =\n{t[1]}\n')
# Out:
# Topic 0 =
# 0.046*"girl" + 0.038*"club" + 0.026*"make" + 0.026*"service" + 0.026*"community" + 0.022*"learn" + 0.022*"coding" + 0.018*"high" + 0.018*"career" + 0.018*"learning"
#
# Topic 1 =
# 0.041*"science" + 0.032*"team" + 0.029*"experiment" + 0.023*"first" + 0.020*"teacher" + 0.020*"well" + 0.016*"grade" + 0.016*"build" + 0.016*"technology" + 0.016*"volunteer"
#
# Topic 2 =
# 0.041*"stem" + 0.032*"summer" + 0.032*"robotics" + 0.028*"learning" + 0.028*"programming" + 0.028*"engineering" + 0.028*"science" + 0.023*"participant" + 0.023*"activity" + 0.019*"week"

# %% [markdown]
# - Weight implies importance of the word to the topic
# - Ideally, we want each topic to be distinct - to have distinct keywords.

# %% [markdown]
# ### Evaluation

# %%
# Aim for lower perplexity
print('Perplexity: ', lda.log_perplexity(programs_corpus))
# Out:
# Perplexity:  -5.050835970435636

# %%
coherence = CoherenceModel(model=lda, 
                           texts=programs_text, 
                           dictionary=programs_dict, 
                           coherence='c_v')
coherence_lda = coherence.get_coherence()

print('Baseline coherence: ', coherence_lda)
# Out:
# Baseline coherence:  0.38025332912182014

# %% [markdown]
# - Topic Coherence measures relative distance between words within a topic.
# - For `C_V`, 0 < coherence < 1. Higher similarity -> Higher coherence.

# %% [markdown]
# ### Tuning K: the optimal number of topics

# %%
def compute_coherence(dictionary=programs_dict, 
                      corpus=programs_corpus, 
                      texts=programs_text, 
                      start=2, end=7, step=1):
    """
    Computes coherence for the LDA models
    given a search space for num_topics defined by (start, end, step).
    Since we only have 13 corpus, we will set end to be 7 
    so that at most 6 topics should be formed for the organization's programs
    """
    coherence = []
    model_list = []
    
    for n_topics in range(start, end, step):
        lda = LdaModel(
            corpus,
            id2word=dictionary,
            num_topics=n_topics, 
            random_state=SEED,
            update_every=1, 
            passes=100,
            alpha='auto',
            chunksize=500)
        
        model_list.append(lda)
        coherence_lda = CoherenceModel(model=lda, 
                                       texts=texts, 
                                       dictionary=dictionary, 
                                       coherence='c_v')
        coherence.append(coherence_lda.get_coherence())
    
    
    x = range(start, end, step)
    plt.plot(x, coherence)
    plt.xlabel('Number of Topics')
    plt.ylabel('Coherence')
    plt.title('Choosing Optimal Number of Topics Based on Coherence')
    plt.show()
    
    # Summarize results
    best_k = x[np.argmax(coherence)]
    print(f'Best Number of Topics: {best_k}')
    print(f'Best coherence: {np.max(coherence)}')
    
    return model_list[np.argmax(coherence)]

# %%
best_lda = compute_coherence()
# Out:
# Best Number of Topics: 5
# Best coherence: 0.41306901109596217

# %%
topics = best_lda.show_topics()
for t in topics:
    print(f'Topic {t[0]} =\n{t[1]}\n')
# Out:
# Topic 0 =
# 0.090*"girl" + 0.032*"provide" + 0.032*"team" + 0.032*"learning" + 0.017*"consistently" + 0.017*"support" + 0.017*"design" + 0.017*"led" + 0.017*"experience" + 0.017*"adult"
#
# Topic 1 =
# 0.056*"science" + 0.046*"experiment" + 0.029*"grade" + 0.026*"girl" + 0.026*"teacher" + 0.025*"volunteer" + 0.021*"well" + 0.021*"session" + 0.021*"middle" + 0.021*"coding"
#
# Topic 2 =
# 0.042*"stem" + 0.033*"learning" + 0.033*"robotics" + 0.029*"programming" + 0.029*"science" + 0.029*"engineering" + 0.029*"summer" + 0.024*"activity" + 0.019*"run" + 0.019*"week"
#
# Topic 3 =
# 0.042*"team" + 0.040*"club" + 0.032*"first" + 0.032*"build" + 0.027*"make" + 0.026*"work" + 0.022*"fun" + 0.022*"year" + 0.022*"lego" + 0.022*"robot"
#
# Topic 4 =
# 0.069*"high" + 0.053*"career" + 0.044*"service" + 0.036*"community" + 0.036*"participate" + 0.027*"sport" + 0.027*"academic" + 0.027*"learning" + 0.027*"development" + 0.027*"opportunity"

# %% [markdown]
# ### Visualization

# %%
vis = pyLDAvis.gensim.prepare(best_lda, programs_corpus, programs_dict)

# %%
pyLDAvis.show(vis)
# Out:
# Note: if you're in the IPython notebook, pyLDAvis.show() is not the best command
#       to use. Consider using pyLDAvis.display(), or pyLDAvis.enable_notebook().
#       See more information at http://pyLDAvis.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [31/Aug/2020 14:28:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Aug/2020 14:28:52] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Aug/2020 14:28:52] "GET /LDAvis.css HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Aug/2020 14:28:52] "GET /LDAvis.js HTTP/1.1" 200 -
# stopping Server...

# %% [markdown]
# - The larger the bubble, the more prevalent is that topic.
# - Ideally, we want to have large, non-overlapping bubbles.
# - For each topic, salient words are shown.

# %% [markdown]
# ### Finding the dominant topic for each organization

# %%
def get_dominant_topic(model=best_lda,
                       corpus=programs_corpus, 
                       texts=programs_text,
                       df=df_cleaned):
    """
    Finds the dominant topic for each corpus (organization)
    """
    # Initiate a dataframe for results
    columns = ['dominant_topic', 'topic_prop', 'topic_keywords']
    results = pd.DataFrame(columns=columns)
    
    # Get the dominant topic
    for i in range(len(corpus)):
        # topics: [(topic, proportion), ...] for corpus i (i-th organization)
        topics = model[corpus[i]]
        # Sort by topic proportion
        top_topic = sorted(topics, key=lambda x: (x[1]), reverse=True)[0]
        # vocabs: [(vocab, weight), ...]
        topic_idx, topic_prop = top_topic[0], top_topic[1]
        vocabs = model.show_topic(topic_idx)
        # Sort by vocabulary proportion
        vocabs = sorted(vocabs, key=lambda x: (x[1]), reverse=True)
        vocabs_list = ', '.join([v for v, _ in vocabs])
        
        res = pd.DataFrame([[topic_idx, topic_prop, vocabs_list]], 
                           columns=columns)
        
        results = pd.concat([results, res]).reset_index(drop=True)
    
    # Stack vertically to the cleaned dataset
    # For integrity, replace duplicates
    if columns in df.columns.tolist(): 
        df = df.drop(columns, axis=1)
    df = pd.concat([df, results], axis=1, verify_integrity=True)
    return df

# %%
df_cleaned = get_dominant_topic()

# %%
df_cleaned
# Out:
#                                  organization  priority  \
# 0                                  JerseySTEM         0
# 1                      After School All Stars         1
# 2                  FIRST Robotics Competition         1
# 3                              Girls Who Code         1
# 4                                   TechGirlz         1
# 5                       South Jersey Robotics         1
# 6                          Students 2 Science         1
# 7                                Bedtime Math         2
# 8                                Girls Scouts         2
# 9                            The Coder School         2
# 10                                STEMKidsNYC         2
# 11  STEM ALLIANCE OF LARCHMONT-MAMARONECK INC         2
# 12                               Digital Girl         2
#
#                                               mission  \
# 0   JerseySTEM is a non-profit organization that p...
# 1   After-School All-Stars provides free, comprehe...
# 2   FIRST LEGO League introduces science, technolo...
# 3   Girls Who Code is on a mission to close the ge...
# 4   TechGirlz is a nonprofit program of Creating I...
# 5   Our Vision:\nTransform the culture in South Je...
# 6   Students 2 Science, Inc. is a 501(c)(3) model ...
# 7   Our charitable mission is to help kids love nu...
# 8   Girl Scouts offers the best leadership develop...
# 9   We are an after-school drop-off (and virtual) ...
# 10  STEM Kids NYC is a 501(c)(3) organization that...
# 11  The STEM Alliance is a grass-roots, 501(c)(3) ...
# 12  Digital Girl, Incorporated was founded in 2014...
#
#                                              programs  \
# 0   MySTEMClub\nLearn Teamwork, Problem Solving, a...
# 1   We Are Ready (W.A.R.) prepares at-risk 8th gra...
# 2   FIRST LEGO League is a program that engages st...
# 3   After-school clubs for 3rd–12th grade girls to...
# 4   TechShopz are free, hands-on technology worksh...
# 5   SJR supports 18 FIRST Robotics teams consistin...
# 6   ISAAC engages middle and high school students ...
# 7   We make math part of the family routine. Every...
# 8   Development of the Girl Scout Leadership Exper...
# 9   Rather than using static one-size-fits-all cur...
# 10  Our hands-on, student centered afterschool pro...
# 11  THE STEM ALLIANCE IS HIRED PY THE MAMARONECK U...
# 12  After School and Summer Enrichment Program (AS...
#
#                                       mission_cleaned  cluster  \
# 0   [promotes, excellence, science, technology, en...        0
# 1   [star, provides, free, comprehensive, keep, ch...        2
# 2   [first, lego, league, introduces, science, tec...        1
# 3   [girl, code, close, gender, gap, technology, c...        2
# 4   [creating, future, comptia, inspires, middle, ...        3
# 5   [vision, transform, culture, south, surroundin...        1
# 6   [science, model, new, bridge, need, public, pr...        0
# 7   [charitable, help, love, number, handle, math,...        2
# 8   [girl, scout, offer, best, leadership, develop...        3
# 9             [drop, virtual, learning, code, coding]        4
# 10  [stem, nyc, provides, year, round, intensive, ...        0
# 11  [stem, alliance, grass, root, dedicated, enhan...        0
# 12  [digital, girl, incorporated, wa, founded, exe...        0
#
#                                     cluster_keywords  \
# 0   stem, education, professional, career, community
# 1                      help, life, close, look, like
# 2             first, robotics, hand, learning, skill
# 3                      help, life, close, look, like
# 4         girl, development, leadership, free, offer
# 5             first, robotics, hand, learning, skill
# 6   stem, education, professional, career, community
# 7                      help, life, close, look, like
# 8         girl, development, leadership, free, offer
# 9             learning, virtual, coding, code, youth
# 10  stem, education, professional, career, community
# 11  stem, education, professional, career, community
# 12  stem, education, professional, career, community
#
#                                      programs_cleaned dominant_topic  \
# 0   [mystemclub, learn, teamwork, problem, solving...              3
# 1   [ready, prepares, risk, grader, success, high,...              4
# 2   [first, lego, league, engages, yr, fun, combin...              3
# 3   [club, grade, girl, explore, coding, fun, frie...              1
# 4   [techshopz, free, hand, technology, workshop, ...              0
# 5   [support, first, robotics, team, consisting, t...              0
# 6   [isaac, engages, middle, high, real, problem, ...              1
# 7   [make, math, part, family, routine, every, ser...              3
# 8   [development, girl, scout, leadership, experie...              0
# 9   [rather, using, static, one, size, fit, curric...              2
# 10  [hand, centered, afterschool, apply, different...              2
# 11  [stem, alliance, hired, mamaroneck, union, fre...              2
# 12  [summer, enrichment, asep, servicing, particip...              3
#
#     topic_prop                                     topic_keywords
# 0     0.619118  team, club, first, build, make, work, fun, yea...
# 1     0.998648  high, career, service, community, participate,...
# 2     0.999249  team, club, first, build, make, work, fun, yea...
# 3     0.997518  science, experiment, grade, girl, teacher, vol...
# 4     0.992558  girl, provide, team, learning, consistently, s...
# 5     0.988366  girl, provide, team, learning, consistently, s...
# 6     0.845808  science, experiment, grade, girl, teacher, vol...
# 7     0.997772  team, club, first, build, make, work, fun, yea...
# 8     0.996084  girl, provide, team, learning, consistently, s...
# 9     0.995468  stem, learning, robotics, programming, science...
# 10    0.999275  stem, learning, robotics, programming, science...
# 11    0.998538  stem, learning, robotics, programming, science...
# 12    0.992480  team, club, first, build, make, work, fun, yea...

# %%
df_cleaned.head(5)
# Out:
#                  organization  priority  \
# 0                  JerseySTEM         0
# 1      After School All Stars         1
# 2  FIRST Robotics Competition         1
# 3              Girls Who Code         1
# 4                   TechGirlz         1
#
#                                              mission  \
# 0  JerseySTEM is a non-profit organization that p...
# 1  After-School All-Stars provides free, comprehe...
# 2  FIRST LEGO League introduces science, technolo...
# 3  Girls Who Code is on a mission to close the ge...
# 4  TechGirlz is a nonprofit program of Creating I...
#
#                                             programs  \
# 0  MySTEMClub\nLearn Teamwork, Problem Solving, a...
# 1  We Are Ready (W.A.R.) prepares at-risk 8th gra...
# 2  FIRST LEGO League is a program that engages st...
# 3  After-school clubs for 3rd–12th grade girls to...
# 4  TechShopz are free, hands-on technology worksh...
#
#                                      mission_cleaned  cluster  \
# 0  [promotes, excellence, science, technology, en...        0
# 1  [star, provides, free, comprehensive, keep, ch...        2
# 2  [first, lego, league, introduces, science, tec...        1
# 3  [girl, code, close, gender, gap, technology, c...        2
# 4  [creating, future, comptia, inspires, middle, ...        3
#
#                                    cluster_keywords  \
# 0  stem, education, professional, career, community
# 1                     help, life, close, look, like
# 2            first, robotics, hand, learning, skill
# 3                     help, life, close, look, like
# 4        girl, development, leadership, free, offer
#
#                                     programs_cleaned dominant_topic  \
# 0  [mystemclub, learn, teamwork, problem, solving...              3
# 1  [ready, prepares, risk, grader, success, high,...              4
# 2  [first, lego, league, engages, yr, fun, combin...              3
# 3  [club, grade, girl, explore, coding, fun, frie...              1
# 4  [techshopz, free, hand, technology, workshop, ...              0
#
#    topic_prop                                     topic_keywords
# 0    0.619118  team, club, first, build, make, work, fun, yea...
# 1    0.998648  high, career, service, community, participate,...
# 2    0.999249  team, club, first, build, make, work, fun, yea...
# 3    0.997518  science, experiment, grade, girl, teacher, vol...
# 4    0.992558  girl, provide, team, learning, consistently, s...

# %% [markdown]
# **Which organizations share the same dominant topic as JerseySTEM?**

# %%
js_topic = int(
    df_cleaned.loc[df_cleaned['organization'] == 'JerseySTEM', 
                   'dominant_topic'])

# %%
cols_of_interest = ['organization','cluster_keywords','topic_keywords']

# %%
df_cleaned[df_cleaned['dominant_topic'] == js_topic]\
[cols_of_interest]
# Out:
#                   organization  \
# 0                   JerseySTEM
# 2   FIRST Robotics Competition
# 7                 Bedtime Math
# 12                Digital Girl
#
#                                     cluster_keywords  \
# 0   stem, education, professional, career, community
# 2             first, robotics, hand, learning, skill
# 7                      help, life, close, look, like
# 12  stem, education, professional, career, community
#
#                                        topic_keywords
# 0   team, club, first, build, make, work, fun, yea...
# 2   team, club, first, build, make, work, fun, yea...
# 7   team, club, first, build, make, work, fun, yea...
# 12  team, club, first, build, make, work, fun, yea...

# %% [markdown]
# ### Finding the most representative organization for each topic

# %%
df_cleaned[['organization','programs', \
            'dominant_topic', 'topic_prop', 'topic_keywords']]\
    .sort_values('topic_prop', ascending=False)\
    .groupby(['dominant_topic', 'topic_keywords']).head(1)
# Out:
#                   organization  \
# 10                 STEMKidsNYC
# 2   FIRST Robotics Competition
# 1       After School All Stars
# 3               Girls Who Code
# 8                 Girls Scouts
#
#                                              programs dominant_topic  \
# 10  Our hands-on, student centered afterschool pro...              2
# 2   FIRST LEGO League is a program that engages st...              3
# 1   We Are Ready (W.A.R.) prepares at-risk 8th gra...              4
# 3   After-school clubs for 3rd–12th grade girls to...              1
# 8   Development of the Girl Scout Leadership Exper...              0
#
#     topic_prop                                     topic_keywords
# 10    0.999275  stem, learning, robotics, programming, science...
# 2     0.999249  team, club, first, build, make, work, fun, yea...
# 1     0.998648  high, career, service, community, participate,...
# 3     0.997518  science, experiment, grade, girl, teacher, vol...
# 8     0.996084  girl, provide, team, learning, consistently, s...

# %% [markdown]
# ## Closing notes
# ### Does the organizations with similar mission statements as JerseySTEM also have similar programs?

# %%
df_cleaned[(df_cleaned['cluster'] == js_cluster) |\
          (df_cleaned['dominant_topic'] == js_topic)]\
[cols_of_interest]
# Out:
#                                  organization  \
# 0                                  JerseySTEM
# 2                  FIRST Robotics Competition
# 6                          Students 2 Science
# 7                                Bedtime Math
# 10                                STEMKidsNYC
# 11  STEM ALLIANCE OF LARCHMONT-MAMARONECK INC
# 12                               Digital Girl
#
#                                     cluster_keywords  \
# 0   stem, education, professional, career, community
# 2             first, robotics, hand, learning, skill
# 6   stem, education, professional, career, community
# 7                      help, life, close, look, like
# 10  stem, education, professional, career, community
# 11  stem, education, professional, career, community
# 12  stem, education, professional, career, community
#
#                                        topic_keywords
# 0   team, club, first, build, make, work, fun, yea...
# 2   team, club, first, build, make, work, fun, yea...
# 6   science, experiment, grade, girl, teacher, vol...
# 7   team, club, first, build, make, work, fun, yea...
# 10  stem, learning, robotics, programming, science...
# 11  stem, learning, robotics, programming, science...
# 12  team, club, first, build, make, work, fun, yea...

# %%
df_cleaned[(df_cleaned['cluster'] == js_cluster) &\
          (df_cleaned['dominant_topic'] == js_topic)]\
['organization']
# Out:
# 0       JerseySTEM
# 12    Digital Girl
# Name: organization, dtype: object

# %% [markdown]
# - Only Digital Girl has both a similar mission and a similar program design.
# - It also seems to be closest point to JerseySTEM in terms of cluster assignment.

# %%
with pd.option_context('display.max_colwidth', -1):
    print(
        df_cleaned.loc[df_cleaned['organization']\
                       .isin(['JerseySTEM', 'Digital Girl']),\
                       ['organization', 'mission', 'programs']]
    )
# Out:
#     organization  \
# 0   JerseySTEM
# 12  Digital Girl
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       mission  \
# 0   JerseySTEM is a non-profit organization that promotes excellence in Science, Technology, Engineering and Math (“STEM”) education among youth and helps them prepare for college and STEM careers. We offer dedicated STEM programs to youth in under-served communities and girls to bridge the STEM and opportunity gaps in the workforce.
# 12  Digital Girl, Incorporated was founded in 2014 by Executive Director, Michelle Gall a Digital Marketing and Branding Professional. Our mission is to encourage inner city youth, especially girls to pursue careers in Science, Technology, Engineering and Math. We are motivated by the United States overall lag in producing an adequate number of STEM professionals and the under representation of women and people of color.\nWomen who work in STEM fields make 33% more than women in non-STEM positions. Uplifting our women is key to bringing this community, and other communities in a similar circumstance, out of poverty. \nThrough early application, hands on training, mentorship, tutoring and social events Digital Girl, Inc. will boost confidence, raise self esteem and STEM career awareness within less fortunate areas to create professionals who can be positive contributors to society.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   programs
# 0   MySTEMClub\nLearn Teamwork, Problem Solving, and Coding! The courses are taught by college students in a virtual environment, and are available for in 5 - 8 grade. Students will learn to build their own app with MIT App Inventor.\nLocal Club Programs\nBridging the Innovation Gap. The Local Club Programs, or Local Makerspaces, serve as the R&D department for JerseySTEM. Programs are tested locally in clubs run by parent volunteers. Some are then offered in our outreach programs or other local clubs.\nOutreach Programs. Bridging the Opportunity Gap. JerseySTEM works with schools and organizations to create after-school STEM Club programs in low income, under-served areas and communities.
# 12  After School and Summer Enrichment Program (ASEP) servicing 500 participants\nYoung Professional Development Program servicing 120 participants\nTechnology Workshops servicing 800 participants
